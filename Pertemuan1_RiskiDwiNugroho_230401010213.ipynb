# %% [markdown]
# <a href="https://colab.research.google.com/github/dnriski/data-science-2026/blob/main/Pertemuan1_RiskiDwiNugroho_230401010213.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Nama   : Riski Dwi Nugroho
#NIM    : 230401010213
#Kelas  : IF403

# %%
# Sel 1: Output Sederhana
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
# Sel 2: Variabel & tipe data
nama ="Riski Dwi Nugroho"
angkatan ="2023"
print(f"Halo, {nama} angkatan {angkatan}!")
# Out:
# Halo, Riski Dwi Nugroho angkatan 2023!

# %%
# Sel 3: List & Perulangan
tools = ["Python","Colab","Jupyter","Github"]
for i, tool in enumerate(tools, 1):
  print(f"{i}. {tool}")
# Out:
# 1. Python
# 2. Colab
# 3. Jupyter
# 4. Github

# %%
# Sel 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Budi","Informatika",2024))
# Out:
# Budi | Informatika | 2024

# %%
# Kesimpulan : Dari yang saya pelajari, ini adalah pengenalan syntax dasar python untuk mulai belajar data science. Kesimpulan tersebut didapat dari kode yang ditulis seperti print, variabel dan list. Pertanyaan yang muncul, apakah banyak syntax dasar yang belum saya pelajari selama di sesi ini.
