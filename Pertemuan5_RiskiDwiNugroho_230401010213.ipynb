# %% [markdown]
# <a href="https://colab.research.google.com/github/dnriski/data-science-2026/blob/main/Pertemuan5_RiskiDwiNugroho_230401010213.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Nama   : Riski Dwi Nugroho
#NIM    : 230401010213
#Kelas  : IF403

# %%
#Immport Data
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, matplotlib.gridspec as gridspec
import seaborn as sns

# %%
df = sns.load_dataset('tips')
print(df.shape, df.dtypes)
print(df.describe().round(2))
# Out:
# (244, 7) total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object
#        total_bill     tip    size
# count      244.00  244.00  244.00
# mean        19.79    3.00    2.57
# std          8.90    1.38    0.95
# min          3.07    1.00    1.00
# 25%         13.35    2.00    2.00
# 50%         17.80    2.90    2.00
# 75%         24.13    3.56    3.00
# max         50.81   10.00    6.00

# %%
fig = plt.figure(figsize=(16, 12))
fig.suptitle('tips', fontsize=20)
# Out:
# Text(0.5, 0.98, 'tips')

# %%
gs = gridspec.GridSpec(2, 2, figure=fig)
ax1 = fig.add_subplot(gs[0, 0]) # kiri atas
ax2 = fig.add_subplot(gs[0, 1]) # kanan atas
ax3 = fig.add_subplot(gs[1, 0]) # kiri bawah
ax4 = fig.add_subplot(gs[1, 1]) # kanan bawah

# %%
# BAR CHART
avg_by_day = df.groupby('day')['total_bill'].mean()
avg_by_day.plot(kind='bar', ax=ax1, color='#028090', edgecolor='white')
ax1.set_title('Rata-rata Total Tagihan per Hari')
ax1.set_xlabel('Hari'); ax1.set_ylabel('Total Bill (USD)')
ax1.tick_params(axis='x', rotation=0)
ax1.spines[['top','right']].set_visible(False)
#
# Out:
# /tmp/ipykernel_15394/1221007323.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_by_day = df.groupby('day')['total_bill'].mean()

# %%
# HISTOGRAM + KDE
sns.histplot(data=df, x='total_bill', hue='time',
kde=True, palette='Set2', ax=ax2)
ax2.set_title('Distribusi Total Tagihan per Waktu Makan')
ax2.spines[['top','right']].set_visible(False)

# %%
# BOXPLOT
sns.boxplot(data=df, x='day', y='total_bill', hue='sex',
palette='Set1', ax=ax3)
ax3.set_title('Total Tagihan per Hari')
# Out:
# Text(0.5, 1.0, 'Total Tagihan per Hari')

# %%
# SCATTER PLOT
sns.scatterplot(data=df, x='total_bill', y='tip',
hue='smoker', palette='Set2', ax=ax4)
ax4.set_title('Hubungan Total Tagihan dan Tip')
ax4.spines[['top','right']].set_visible(False)

# %%
plt.tight_layout()
fig.savefig('tips.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
#Kesimpulan : Pada sesi ini yang dipelajari yakni cara melakukan visualisasi data dengan berbagai jenis chart seperti bar chart dan histogram. Data chart tersebut berhasil di simpan dalam format png, grafik tersebut menyimpulkan bahwa semakin besar total tagihan maka umumnya semakin besar pula tip yang diberikan pelanggan. Pertanyaan yang muncul lebih kepada pemilihan kesesuain chart sesuai dengan kondisi data yang akan ditampilkan
